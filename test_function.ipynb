# %% [markdown]
# # Test mask Detection in the wild

# %%
import os
from Code.MaskDetection import MaskDetection

# Get the project directory from the current notebook location
NOTEBOOK_DIR = os.getcwd()
PROJECT_DIR = os.path.abspath(os.path.join(NOTEBOOK_DIR))
PERSONAL_DATASET_PATH = os.path.join(PROJECT_DIR, 'personal_dataset', 'images')

# Run detection
MaskDetection(PERSONAL_DATASET_PATH)
